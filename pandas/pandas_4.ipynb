# %% [markdown]
# # Pandas'da Cokca Kullanilan Fonksiyon ve Metodlar

# %% [markdown]
# Bütün fonksiyon ve methodları görebilmek için bu [dökümantasyon](https://pandas.pydata.org/pandas-docs/stable/reference/index.html) incelenebilir.
#
# * [apply() method](#apply_method)
# * [apply() with a function](#apply_function)
# * [apply() with a lambda expression](#apply_lambda)
# * [apply() on multiple columns](#apply_multiple)
# * [describe()](#describe)
# * [sort_values()](#sort)
# * [corr()](#corr)
# * [idxmin and idxmax](#idx)
# * [value_counts()](#v_c)
# * [replace()](#replace)
# * [unique and nunique()](#uni)
# * [map()](#map)
# * [duplicated and drop_duplicates()](#dup)
# * [between()](#bet)
# * [sample()](#sample)
# * [nlargest()](#n)

# %%
import pandas as pd
import numpy as np

# %%
df_tips = pd.read_csv("tips.csv")
df_tips
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# 0    Christy Cunningham  3560325168603410    Sun2959
# 1        Douglas Tucker  4478071379779230    Sun4608
# 2        Travis Walters  6011812112971322    Sun4458
# 3      Nathaniel Harris  4676137647685994    Sun5260
# 4          Tonya Carter  4832732618637221    Sun2251
# ..                  ...               ...        ...
# 239       Michael Avila  5296068606052842    Sat2657
# 240      Monica Sanders  3506806155565404    Sat1766
# 241          Keith Wong  6011891618747196    Sat3880
# 242        Dennis Dixon     4375220550950      Sat17
# 243     Michelle Hardin  3511451626698139    Thur672
#
# [244 rows x 11 columns]

# %%
df_tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        244 non-null    float64
#  1   tip               244 non-null    float64
#  2   sex               244 non-null    object
#  3   smoker            244 non-null    object
#  4   day               244 non-null    object
#  5   time              244 non-null    object
#  6   size              244 non-null    int64
#  7   price_per_person  244 non-null    float64
#  8   Payer Name        244 non-null    object
#  9   CC Number         244 non-null    int64
#  10  Payment ID        244 non-null    object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 21.1+ KB

# %% [markdown]
# ***.apply() metodu***

# %%
# bir series ya da dataframe'in sutunlarindaki her bir elemanina fonksiyon uygulamak icin kullanilir
# arkaplanda for dongusu kullanir

# %% [markdown]
# ## 1. Yol

# %%
def son_4(sayi): # icine yazilan sayiyi stringe cevirip son 4 karakterini donduren fonksiyon
    return str(sayi)[-4:]

# %%
df_tips["CC Number"].apply(son_4) # gecici olarak son 4 karakteri gosterir
# Out:
# 0      3410
# 1      9230
# 2      1322
# 3      5994
# 4      7221
#        ...
# 239    2842
# 240    5404
# 241    7196
# 242    0950
# 243    8139
# Name: CC Number, Length: 244, dtype: object

# %%
df_tips["CC Number"] = df_tips["CC Number"].apply(son_4) # kalici olarak son 4 karakteri atar
df_tips
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name CC Number Payment ID
# 0    Christy Cunningham      3410    Sun2959
# 1        Douglas Tucker      9230    Sun4608
# 2        Travis Walters      1322    Sun4458
# 3      Nathaniel Harris      5994    Sun5260
# 4          Tonya Carter      7221    Sun2251
# ..                  ...       ...        ...
# 239       Michael Avila      2842    Sat2657
# 240      Monica Sanders      5404    Sat1766
# 241          Keith Wong      7196    Sat3880
# 242        Dennis Dixon      0950      Sat17
# 243     Michelle Hardin      8139    Thur672
#
# [244 rows x 11 columns]

# %% [markdown]
# ## 2. Yol

# %%
df_tips = pd.read_csv("tips.csv")
df_tips
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# 0    Christy Cunningham  3560325168603410    Sun2959
# 1        Douglas Tucker  4478071379779230    Sun4608
# 2        Travis Walters  6011812112971322    Sun4458
# 3      Nathaniel Harris  4676137647685994    Sun5260
# 4          Tonya Carter  4832732618637221    Sun2251
# ..                  ...               ...        ...
# 239       Michael Avila  5296068606052842    Sat2657
# 240      Monica Sanders  3506806155565404    Sat1766
# 241          Keith Wong  6011891618747196    Sat3880
# 242        Dennis Dixon     4375220550950      Sat17
# 243     Michelle Hardin  3511451626698139    Thur672
#
# [244 rows x 11 columns]

# %%
df_tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df_tips["CC Number"].apply(lambda sayi : str(sayi)[-4:]) # ayni islemi lambda ile yapma
# Out:
# 0      3410
# 1      9230
# 2      1322
# 3      5994
# 4      7221
#        ...
# 239    2842
# 240    5404
# 241    7196
# 242    0950
# 243    8139
# Name: CC Number, Length: 244, dtype: object

# %%
df_tips["CC Number"] = df_tips["CC Number"].apply(son_4) # kalici olarak son 4 karakteri atar
df_tips
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name CC Number Payment ID
# 0    Christy Cunningham      3410    Sun2959
# 1        Douglas Tucker      9230    Sun4608
# 2        Travis Walters      1322    Sun4458
# 3      Nathaniel Harris      5994    Sun5260
# 4          Tonya Carter      7221    Sun2251
# ..                  ...       ...        ...
# 239       Michael Avila      2842    Sat2657
# 240      Monica Sanders      5404    Sat1766
# 241          Keith Wong      7196    Sat3880
# 242        Dennis Dixon      0950      Sat17
# 243     Michelle Hardin      8139    Thur672
#
# [244 rows x 11 columns]

# %% [markdown]
# ## 3. Yol (Vektorize Edilmis)(En Hizli Yol)

# %%
df_tips = pd.read_csv("tips.csv")
df_tips
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# 0    Christy Cunningham  3560325168603410    Sun2959
# 1        Douglas Tucker  4478071379779230    Sun4608
# 2        Travis Walters  6011812112971322    Sun4458
# 3      Nathaniel Harris  4676137647685994    Sun5260
# 4          Tonya Carter  4832732618637221    Sun2251
# ..                  ...               ...        ...
# 239       Michael Avila  5296068606052842    Sat2657
# 240      Monica Sanders  3506806155565404    Sat1766
# 241          Keith Wong  6011891618747196    Sat3880
# 242        Dennis Dixon     4375220550950      Sat17
# 243     Michelle Hardin  3511451626698139    Thur672
#
# [244 rows x 11 columns]

# %%
df_tips["CC Number"]
# Out:
# 0      3560325168603410
# 1      4478071379779230
# 2      6011812112971322
# 3      4676137647685994
# 4      4832732618637221
#              ...
# 239    5296068606052842
# 240    3506806155565404
# 241    6011891618747196
# 242       4375220550950
# 243    3511451626698139
# Name: CC Number, Length: 244, dtype: int64

# %%
df_tips["CC Number"].astype(str).str[-4:] # vektorize edilmis hali, en hizli yol
# Out:
# 0      3410
# 1      9230
# 2      1322
# 3      5994
# 4      7221
#        ...
# 239    2842
# 240    5404
# 241    7196
# 242    0950
# 243    8139
# Name: CC Number, Length: 244, dtype: object

# %% [markdown]
# # lambda ile uygulanan yol

# %%
df_tips = pd.read_csv("tips.csv")
df_tips
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# 0    Christy Cunningham  3560325168603410    Sun2959
# 1        Douglas Tucker  4478071379779230    Sun4608
# 2        Travis Walters  6011812112971322    Sun4458
# 3      Nathaniel Harris  4676137647685994    Sun5260
# 4          Tonya Carter  4832732618637221    Sun2251
# ..                  ...               ...        ...
# 239       Michael Avila  5296068606052842    Sat2657
# 240      Monica Sanders  3506806155565404    Sat1766
# 241          Keith Wong  6011891618747196    Sat3880
# 242        Dennis Dixon     4375220550950      Sat17
# 243     Michelle Hardin  3511451626698139    Thur672
#
# [244 rows x 11 columns]

# %%
df_tips["fiyat_kategorisi"] = df_tips["total_bill"].apply(lambda x: "$" if x < 15 else ("$$" if x < 30 else "$$$"))
# total_bill degerine gore fiyat_kategorisi adinda yeni bir sutun ekler

# %%
df_tips.sample(10)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 171       15.81  3.16    Male    Yes   Sat  Dinner     2              7.90
# 181       23.33  5.65    Male    Yes   Sun  Dinner     2             11.66
# 190       15.69  1.50    Male    Yes   Sun  Dinner     2              7.84
# 19        20.65  3.35    Male     No   Sat  Dinner     3              6.88
# 6          8.77  2.00    Male     No   Sun  Dinner     2              4.38
# 223       15.98  3.00  Female     No   Fri   Lunch     3              5.33
# 72        26.86  3.14  Female    Yes   Sat  Dinner     2             13.43
# 205       16.47  3.23  Female    Yes  Thur   Lunch     3              5.49
# 27        12.69  2.00    Male     No   Sat  Dinner     2              6.34
# 16        10.33  1.67  Female     No   Sun  Dinner     3              3.44
#
#              Payer Name         CC Number Payment ID fiyat_kategorisi
# 171          David Hall      502004138207    Sat6750               $$
# 181           Jason Cox  6556931703586223    Sun3402               $$
# 190        Riley Barnes   180053549128800    Sun5104               $$
# 19        Timothy Oneal  6568069240986485    Sat9213               $$
# 6    Kristopher Johnson  2223727524230344    Sun5985                $
# 223         Mary Rivera  5343428579353069    Fri6014               $$
# 72   Victoria Obrien MD     4216245673726    Sat1967               $$
# 205         Carly Reyes     4787787236486   Thur8084               $$
# 27       Patrick Barber    30155551880343     Sat394                $
# 16     Elizabeth Foster  4240025044626033    Sun9715                $

# %% [markdown]
# # vektorize sekilde uygulanan yol

# %%
df_tips = pd.read_csv("tips.csv")
df_tips
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# 0    Christy Cunningham  3560325168603410    Sun2959
# 1        Douglas Tucker  4478071379779230    Sun4608
# 2        Travis Walters  6011812112971322    Sun4458
# 3      Nathaniel Harris  4676137647685994    Sun5260
# 4          Tonya Carter  4832732618637221    Sun2251
# ..                  ...               ...        ...
# 239       Michael Avila  5296068606052842    Sat2657
# 240      Monica Sanders  3506806155565404    Sat1766
# 241          Keith Wong  6011891618747196    Sat3880
# 242        Dennis Dixon     4375220550950      Sat17
# 243     Michelle Hardin  3511451626698139    Thur672
#
# [244 rows x 11 columns]

# %%
def fiyat_kategori_vectorized(odeme): 
    kategori = np.full_like(odeme, "$", dtype = "<U3") # <U3 => unicode string 3 karaktere kadar
    
    kategori[(odeme > 10) & (odeme <= 30)] = "$$"
    
    kategori[odeme >= 30] = "$$$"
    
    return kategori

# %%
fiyat_kategori_vectorized(df_tips["total_bill"].values)
# Out:
# array(['$$', '$$', '$$', '$$', '$$', '$$', '$', '$$', '$$', '$$', '$$',
#        '$$$', '$$', '$$', '$$', '$$', '$$', '$$', '$$', '$$', '$$', '$$',
#        '$$', '$$$', '$$', '$$', '$$', '$$', '$$', '$$', '$', '$$', '$$',
#        '$$', '$$', '$$', '$$', '$$', '$$', '$$$', '$$', '$$', '$$', '$',
#        '$$$', '$$', '$$', '$$$', '$$', '$$', '$$', '$$', '$$$', '$', '$$',
#        '$$', '$$$', '$$', '$$', '$$$', '$$', '$$', '$$', '$$', '$$', '$$',
#        '$$', '$', '$$', '$$', '$$', '$$', '$$', '$$', '$$', '$$', '$$',
#        '$$', '$$', '$$', '$$', '$$', '$$', '$$$', '$$', '$$$', '$$', '$$',
#        '$$', '$$', '$$', '$$', '$', '$$', '$$', '$$$', '$$', '$$', '$$',
#        '$$', '$$', '$$', '$$$', '$$', '$$', '$$', '$$', '$$', '$$', '$$',
#        '$$', '$', '$$$', '$$', '$$', '$$', '$$', '$$', '$$', '$$', '$$',
#        '$$', '$$', '$$', '$$', '$$', '$', '$$', '$$', '$$', '$$', '$$',
#        '$$', '$$', '$$', '$', '$$', '$$', '$$', '$$', '$$', '$$$', '$$$',
#        '$$', '$$', '$', '$$', '$$', '$', '$', '$$', '$$', '$$', '$$',
#        '$$', '$$', '$$$', '$$', '$$', '$$', '$$', '$$', '$$', '$$', '$$',
#        '$$', '$$', '$$$', '$$', '$$', '$$$', '$$', '$', '$$$', '$$',
#        '$$$', '$$', '$$', '$', '$$$', '$$$', '$$', '$$$', '$$', '$$$',
#        '$$', '$$', '$$$', '$$', '$$', '$$', '$$', '$$', '$$', '$$', '$',
#        '$$', '$$$', '$$', '$$', '$$', '$$', '$$', '$$', '$$', '$$', '$$',
#        '$$$', '$$', '$$', '$$$', '$$', '$$$', '$$', '$$', '$$', '$$',
#        '$$', '$', '$$$', '$$', '$$', '$', '$$', '$$', '$$', '$$', '$$',
#        '$$', '$$', '$$', '$$', '$$', '$$', '$$', '$$', '$$', '$$$', '$$$',
#        '$$', '$$', '$$', '$$', '$$'], dtype='<U3')

# %%
df_tips["fiyat_kategorisi_vektorize"] = fiyat_kategori_vectorized(df_tips["total_bill"].values)

# %%
df_tips.sample(10)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 53         9.94  1.56    Male     No   Sun  Dinner     2              4.97
# 180       34.65  3.68    Male    Yes   Sun  Dinner     4              8.66
# 213       13.27  2.50  Female    Yes   Sat  Dinner     2              6.64
# 32        15.06  3.00  Female     No   Sat  Dinner     2              7.53
# 215       12.90  1.10  Female    Yes   Sat  Dinner     2              6.45
# 33        20.69  2.45  Female     No   Sat  Dinner     4              5.17
# 125       29.80  4.20  Female     No  Thur   Lunch     6              4.97
# 115       17.31  3.50  Female     No   Sun  Dinner     2              8.65
# 221       13.42  3.48  Female    Yes   Fri   Lunch     2              6.71
# 220       12.16  2.20    Male    Yes   Fri   Lunch     2              6.08
#
#            Payer Name         CC Number Payment ID fiyat_kategorisi_vektorize
# 53      Curtis Morgan  4628628020417301    Sun4561                          $
# 180  James Hebert DDS      676168737648    Sun7544                        $$$
# 213    Robin Andersen      580140531089    Sat1374                         $$
# 32      Amanda Wilson   213186304291560    Sat1327                         $$
# 215      Jessica Owen     4726904879471    Sat6983                         $$
# 33      Amber Francis   377742985258914    Sat6649                         $$
# 125    Angela Sanchez      503857080488   Thur3948                         $$
# 115       Kayla Stone   379494319310858    Sun8746                         $$
# 221    Leslie Kaufman   379437981958785    Fri7511                         $$
# 220     Ricky Johnson   213109508670736    Fri4607                         $$

# %% [markdown]
# ## .apply() birden fazla sutuna uygulanabilir

# %%
df_tips = pd.read_csv("tips.csv")
df_tips
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# 0    Christy Cunningham  3560325168603410    Sun2959
# 1        Douglas Tucker  4478071379779230    Sun4608
# 2        Travis Walters  6011812112971322    Sun4458
# 3      Nathaniel Harris  4676137647685994    Sun5260
# 4          Tonya Carter  4832732618637221    Sun2251
# ..                  ...               ...        ...
# 239       Michael Avila  5296068606052842    Sat2657
# 240      Monica Sanders  3506806155565404    Sat1766
# 241          Keith Wong  6011891618747196    Sat3880
# 242        Dennis Dixon     4375220550950      Sat17
# 243     Michelle Hardin  3511451626698139    Thur672
#
# [244 rows x 11 columns]

# %%
df_tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
def dort_ekle(sayi):
    return sayi + 4

# %%
df_tips[["total_bill", "tip"]].apply(dort_ekle)
# Out:
#      total_bill   tip
# 0         20.99  5.01
# 1         14.34  5.66
# 2         25.01  7.50
# 3         27.68  7.31
# 4         28.59  7.61
# ..          ...   ...
# 239       33.03  9.92
# 240       31.18  6.00
# 241       26.67  6.00
# 242       21.82  5.75
# 243       22.78  7.00
#
# [244 rows x 2 columns]

# %%
# lambda ile ayni islem
df_tips[["total_bill", "tip"]].apply(lambda x : x + 4)
# Out:
#      total_bill   tip
# 0         20.99  5.01
# 1         14.34  5.66
# 2         25.01  7.50
# 3         27.68  7.31
# 4         28.59  7.61
# ..          ...   ...
# 239       33.03  9.92
# 240       31.18  6.00
# 241       26.67  6.00
# 242       21.82  5.75
# 243       22.78  7.00
#
# [244 rows x 2 columns]

# %%
df_tips.describe()
# Out:
#        total_bill         tip        size  price_per_person     CC Number
# count  244.000000  244.000000  244.000000        244.000000  2.440000e+02
# mean    19.785943    2.998279    2.569672          7.888197  2.563496e+15
# std      8.902412    1.383638    0.951100          2.914234  2.369340e+15
# min      3.070000    1.000000    1.000000          2.880000  6.040679e+10
# 25%     13.347500    2.000000    2.000000          5.800000  3.040731e+13
# 50%     17.795000    2.900000    2.000000          7.255000  3.525318e+15
# 75%     24.127500    3.562500    3.000000          9.390000  4.553675e+15
# max     50.810000   10.000000    6.000000         20.270000  6.596454e+15

# %%
df_tips.sort_values(by = "total_bill", ascending = False) # total_bill sutununa gore buyukten kucuge siralamak (gecici)
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 156       48.17   5.00    Male     No   Sun  Dinner     6              8.03
# 182       45.35   3.50    Male    Yes   Sun  Dinner     3             15.12
# ..          ...    ...     ...    ...   ...     ...   ...               ...
# 149        7.51   2.00    Male     No  Thur   Lunch     2              3.76
# 111        7.25   1.00  Female     No   Sat  Dinner     1              7.25
# 172        7.25   5.15    Male    Yes   Sun  Dinner     2              3.62
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2              2.88
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1              3.07
#
#           Payer Name         CC Number Payment ID
# 170    Gregory Clark  5473850968388236    Sat1954
# 212  Alex Williamson      676218815212    Sat4590
# 59       Brian Ortiz  6596453823950595    Sat8139
# 156    Ryan Gonzales  3523151482063321    Sun7518
# 182     Jose Parsons  4112207559459910    Sun2337
# ..               ...               ...        ...
# 149   Daniel Robbins  4823139288341889   Thur6321
# 111      Terri Jones  3559221007826887    Sat4801
# 172      Larry White    30432617123103    Sun9209
# 92      Leah Ramirez  3508911676966392    Fri3780
# 67     Tiffany Brock  4359488526995267    Sat3455
#
# [244 rows x 11 columns]

# %%
df_tips.sort_values(by = "total_bill", ascending = True) # total_bill sutununa gore kucukten buyuge siralamak (gecici)
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1              3.07
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2              2.88
# 111        7.25   1.00  Female     No   Sat  Dinner     1              7.25
# 172        7.25   5.15    Male    Yes   Sun  Dinner     2              3.62
# 149        7.51   2.00    Male     No  Thur   Lunch     2              3.76
# ..          ...    ...     ...    ...   ...     ...   ...               ...
# 182       45.35   3.50    Male    Yes   Sun  Dinner     3             15.12
# 156       48.17   5.00    Male     No   Sun  Dinner     6              8.03
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
#
#           Payer Name         CC Number Payment ID
# 67     Tiffany Brock  4359488526995267    Sat3455
# 92      Leah Ramirez  3508911676966392    Fri3780
# 111      Terri Jones  3559221007826887    Sat4801
# 172      Larry White    30432617123103    Sun9209
# 149   Daniel Robbins  4823139288341889   Thur6321
# ..               ...               ...        ...
# 182     Jose Parsons  4112207559459910    Sun2337
# 156    Ryan Gonzales  3523151482063321    Sun7518
# 59       Brian Ortiz  6596453823950595    Sat8139
# 212  Alex Williamson      676218815212    Sat4590
# 170    Gregory Clark  5473850968388236    Sat1954
#
# [244 rows x 11 columns]

# %%
df_tips.sort_values(by = "total_bill", ascending = True).reset_index() # indexleri de yeniden duzenleyerek siralama yapar
# reset_index ile eski indexler yeni bir sutun olarak eklenir, drop = True ile eski indexler eklenmez
# Out:
#      index  total_bill    tip     sex smoker   day    time  size  \
# 0       67        3.07   1.00  Female    Yes   Sat  Dinner     1
# 1       92        5.75   1.00  Female    Yes   Fri  Dinner     2
# 2      111        7.25   1.00  Female     No   Sat  Dinner     1
# 3      172        7.25   5.15    Male    Yes   Sun  Dinner     2
# 4      149        7.51   2.00    Male     No  Thur   Lunch     2
# ..     ...         ...    ...     ...    ...   ...     ...   ...
# 239    182       45.35   3.50    Male    Yes   Sun  Dinner     3
# 240    156       48.17   5.00    Male     No   Sun  Dinner     6
# 241     59       48.27   6.73    Male     No   Sat  Dinner     4
# 242    212       48.33   9.00    Male     No   Sat  Dinner     4
# 243    170       50.81  10.00    Male    Yes   Sat  Dinner     3
#
#      price_per_person       Payer Name         CC Number Payment ID
# 0                3.07    Tiffany Brock  4359488526995267    Sat3455
# 1                2.88     Leah Ramirez  3508911676966392    Fri3780
# 2                7.25      Terri Jones  3559221007826887    Sat4801
# 3                3.62      Larry White    30432617123103    Sun9209
# 4                3.76   Daniel Robbins  4823139288341889   Thur6321
# ..                ...              ...               ...        ...
# 239             15.12     Jose Parsons  4112207559459910    Sun2337
# 240              8.03    Ryan Gonzales  3523151482063321    Sun7518
# 241             12.07      Brian Ortiz  6596453823950595    Sat8139
# 242             12.08  Alex Williamson      676218815212    Sat4590
# 243             16.94    Gregory Clark  5473850968388236    Sat1954
#
# [244 rows x 12 columns]

# %%
df_tips.sort_values(by = ["tip", "total_bill"], ascending = True).reset_index(drop = True) 
# once tip sonra total_bill sutununa gore siralama yapar
# tip ayni olanlar arasinda total_bill e gore siralama yapar
# drop = True ile eski indexler eklenmez
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 0          3.07   1.00  Female    Yes   Sat  Dinner     1              3.07
# 1          5.75   1.00  Female    Yes   Fri  Dinner     2              2.88
# 2          7.25   1.00  Female     No   Sat  Dinner     1              7.25
# 3         12.60   1.00    Male    Yes   Sat  Dinner     2              6.30
# 4         16.99   1.01  Female     No   Sun  Dinner     2              8.49
# ..          ...    ...     ...    ...   ...     ...   ...               ...
# 239       34.30   6.70    Male     No  Thur   Lunch     6              5.72
# 240       48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 241       39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 242       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 243       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
#
#              Payer Name         CC Number Payment ID
# 0         Tiffany Brock  4359488526995267    Sat3455
# 1          Leah Ramirez  3508911676966392    Fri3780
# 2           Terri Jones  3559221007826887    Sat4801
# 3         Matthew Myers  3543676378973965    Sat5032
# 4    Christy Cunningham  3560325168603410    Sun2959
# ..                  ...               ...        ...
# 239      Steven Carlson  3526515703718508   Thur1025
# 240         Brian Ortiz  6596453823950595    Sat8139
# 241      Lance Peterson  3542584061609808     Sat239
# 242     Alex Williamson      676218815212    Sat4590
# 243       Gregory Clark  5473850968388236    Sat1954
#
# [244 rows x 11 columns]

# %%
df_tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df_tips["price_per_person"].max() # price_per_person sutunundaki en yuksek degeri dondurur
# Out:
# np.float64(20.27)

# %%
df_tips["price_per_person"].argmax() # price_per_person sutunundaki en yuksek degerin indexini dondurur
# Out:
# np.int64(184)

# %%
df_tips["price_per_person"].idxmax() # price_per_person sutunundaki en yuksek degerin indexini dondurur
# Out:
# 184

# %%
df_tips["price_per_person"].min() # price_per_person sutunundaki en dusuk degeri dondurur
# Out:
# np.float64(2.88)

# %%
df_tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        244 non-null    float64
#  1   tip               244 non-null    float64
#  2   sex               244 non-null    object
#  3   smoker            244 non-null    object
#  4   day               244 non-null    object
#  5   time              244 non-null    object
#  6   size              244 non-null    int64
#  7   price_per_person  244 non-null    float64
#  8   Payer Name        244 non-null    object
#  9   CC Number         244 non-null    int64
#  10  Payment ID        244 non-null    object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 21.1+ KB

# %%
df_tips.corr(numeric_only = True) # sayisal sutunlar arasindaki korelasyon katsayilarini dondurur
# makine ogrenmesi ve istatistikte degiskenler arasindaki iliskiyi anlamak icin kullanilir, onemlidir
# Out:
#                   total_bill       tip      size  price_per_person  CC Number
# total_bill          1.000000  0.675734  0.598315          0.647554   0.104576
# tip                 0.675734  1.000000  0.489299          0.347405   0.110857
# size                0.598315  0.489299  1.000000         -0.175359  -0.030239
# price_per_person    0.647554  0.347405 -0.175359          1.000000   0.135240
# CC Number           0.104576  0.110857 -0.030239          0.135240   1.000000

# %%
df_tips["sex"].value_counts() # herhangi bir sutundaki benzersiz degerlerin sayisini dondurur
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
df_tips.day.value_counts() # day sutunundaki benzersiz degerlerin sayisini dondurur
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
df_tips.total_bill.sum() # total_bill sutunundaki degerlerin toplamini dondurur
# Out:
# np.float64(4827.77)

# %%
df_tips.tip.mean() # tip sutunundaki degerlerin ortalamasini dondurur
# Out:
# np.float64(2.99827868852459)

# %%
df_tips.day.unique() # day sutunundaki benzersiz degerleri dondurur
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %%
df_tips.day.nunique() # day sutunundaki benzersiz degerlerin sayisini dondurur
# Out:
# 4

# %% [markdown]
# # Sex Sutunundaki "Male" olanlari "M", "Female" olanlari "F" haline getirmek

# %% [markdown]
# ### 1. Yol (.apply())

# %%
df_tips["sex"].apply(lambda x : "M" if x == "Male" else "F") # "Male" olanlari "M", "Female" olanlari "F"
# Out:
# 0      F
# 1      M
# 2      M
# 3      M
# 4      F
#       ..
# 239    M
# 240    F
# 241    M
# 242    M
# 243    F
# Name: sex, Length: 244, dtype: object

# %% [markdown]
# ### 2. Yol (.replace())

# %%
df_tips.sex.replace(["Male", "Female"], ["M", "F"], inplace = False)
# iki deger verdigimizde liste icinde vermemiz gerekir, ilk liste icindeki degerler ikinci liste icindeki degerlerle degistirilir
# Out:
# 0      F
# 1      M
# 2      M
# 3      M
# 4      F
#       ..
# 239    M
# 240    F
# 241    M
# 242    M
# 243    F
# Name: sex, Length: 244, dtype: object

# %% [markdown]
# ### 3. Yol (.map())

# %%
df_tips.sex.map({"Male" : "M", "Female" : "F"})
# key-value seklinde sozluk yapisi kullanilir
# Out:
# 0      F
# 1      M
# 2      M
# 3      M
# 4      F
#       ..
# 239    M
# 240    F
# 241    M
# 242    M
# 243    F
# Name: sex, Length: 244, dtype: object

# %%
df_tips
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# 0    Christy Cunningham  3560325168603410    Sun2959
# 1        Douglas Tucker  4478071379779230    Sun4608
# 2        Travis Walters  6011812112971322    Sun4458
# 3      Nathaniel Harris  4676137647685994    Sun5260
# 4          Tonya Carter  4832732618637221    Sun2251
# ..                  ...               ...        ...
# 239       Michael Avila  5296068606052842    Sat2657
# 240      Monica Sanders  3506806155565404    Sat1766
# 241          Keith Wong  6011891618747196    Sat3880
# 242        Dennis Dixon     4375220550950      Sat17
# 243     Michelle Hardin  3511451626698139    Thur672
#
# [244 rows x 11 columns]

# %%
df_tips
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# 0    Christy Cunningham  3560325168603410    Sun2959
# 1        Douglas Tucker  4478071379779230    Sun4608
# 2        Travis Walters  6011812112971322    Sun4458
# 3      Nathaniel Harris  4676137647685994    Sun5260
# 4          Tonya Carter  4832732618637221    Sun2251
# ..                  ...               ...        ...
# 239       Michael Avila  5296068606052842    Sat2657
# 240      Monica Sanders  3506806155565404    Sat1766
# 241          Keith Wong  6011891618747196    Sat3880
# 242        Dennis Dixon     4375220550950      Sat17
# 243     Michelle Hardin  3511451626698139    Thur672
#
# [244 rows x 11 columns]

# %%
simple_df = pd.DataFrame(data = [[1, 2, 2, 2], [1, 2, 3, 4], [1, 2, 2, 2], [1, 2, 2, 2]], index = ["A", "B", "C", "D"], columns = ["col1", "col2", "col3", "col4"])
simple_df
# Out:
#    col1  col2  col3  col4
# A     1     2     2     2
# B     1     2     3     4
# C     1     2     2     2
# D     1     2     2     2

# %%
simple_df.duplicated()
# Out:
# A    False
# B    False
# C     True
# D     True
# dtype: bool

# %%
simple_df.drop_duplicates() # tekrar eden satirlari siler, kalici degisiklik icin inplace = True kullanilir
# Out:
#    col1  col2  col3  col4
# A     1     2     2     2
# B     1     2     3     4

# %%
simple_df
# Out:
#    col1  col2  col3  col4
# A     1     2     2     2
# B     1     2     3     4
# C     1     2     2     2
# D     1     2     2     2

# %%
simple_df.drop_duplicates(keep = "last") # tekrar eden satirlardan sonuncusunu tutar, ilklerini siler
# Out:
#    col1  col2  col3  col4
# B     1     2     3     4
# D     1     2     2     2

# %%
simple_df.drop_duplicates(keep = False) # tekrar eden tum satirlari siler
# Out:
#    col1  col2  col3  col4
# B     1     2     3     4

# %%
df_tips[(df_tips["total_bill"] > 10) | (df_tips["total_bill"] < 20)] # total_bill degeri 10'dan buyuk veya 20'den kucuk olan satirlari dondurur
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# 0    Christy Cunningham  3560325168603410    Sun2959
# 1        Douglas Tucker  4478071379779230    Sun4608
# 2        Travis Walters  6011812112971322    Sun4458
# 3      Nathaniel Harris  4676137647685994    Sun5260
# 4          Tonya Carter  4832732618637221    Sun2251
# ..                  ...               ...        ...
# 239       Michael Avila  5296068606052842    Sat2657
# 240      Monica Sanders  3506806155565404    Sat1766
# 241          Keith Wong  6011891618747196    Sat3880
# 242        Dennis Dixon     4375220550950      Sat17
# 243     Michelle Hardin  3511451626698139    Thur672
#
# [244 rows x 11 columns]

# %%
df_tips[df_tips["total_bill"].between(10, 20)] # total_bill degeri 10 ile 20 arasinda olan satirlari dondurur (10 ve 20 dahil)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 8         15.04  1.96    Male     No   Sun  Dinner     2              7.52
# 9         14.78  3.23    Male     No   Sun  Dinner     2              7.39
# 10        10.27  1.71    Male     No   Sun  Dinner     2              5.14
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2              7.76
# 235       10.07  1.25    Male     No   Sat  Dinner     2              5.04
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2              6.30
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# 0    Christy Cunningham  3560325168603410    Sun2959
# 1        Douglas Tucker  4478071379779230    Sun4608
# 8       Joseph Mcdonald  3522866365840377    Sun6820
# 9         Jerome Abbott  3532124519049786    Sun3775
# 10        William Riley      566287581219    Sun2546
# ..                  ...               ...        ...
# 234       Tracy Douglas  4097938155941930    Sat7220
# 235       Sean Gonzalez  3534021246117605    Sat4615
# 236       Matthew Myers  3543676378973965    Sat5032
# 242        Dennis Dixon     4375220550950      Sat17
# 243     Michelle Hardin  3511451626698139    Thur672
#
# [130 rows x 11 columns]

# %%
df_tips[~(df_tips["total_bill"].between(10, 20))] # total_bill degeri 10 ile 20 arasinda olmayan satirlari dondurur
# Out:
#      total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 2         21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No  Sun  Dinner     4              6.15
# 5         25.29  4.71    Male     No  Sun  Dinner     4              6.32
# 6          8.77  2.00    Male     No  Sun  Dinner     2              4.38
# ..          ...   ...     ...    ...  ...     ...   ...               ...
# 237       32.83  1.17    Male    Yes  Sat  Dinner     2             16.42
# 238       35.83  4.67  Female     No  Sat  Dinner     3             11.94
# 239       29.03  5.92    Male     No  Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes  Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes  Sat  Dinner     2             11.34
#
#              Payer Name         CC Number Payment ID
# 2        Travis Walters  6011812112971322    Sun4458
# 3      Nathaniel Harris  4676137647685994    Sun5260
# 4          Tonya Carter  4832732618637221    Sun2251
# 5            Erik Smith   213140353657882    Sun9679
# 6    Kristopher Johnson  2223727524230344    Sun5985
# ..                  ...               ...        ...
# 237        Thomas Brown  4284722681265508    Sat2929
# 238      Kimberly Crane      676184013727    Sat9777
# 239       Michael Avila  5296068606052842    Sat2657
# 240      Monica Sanders  3506806155565404    Sat1766
# 241          Keith Wong  6011891618747196    Sat3880
#
# [114 rows x 11 columns]

# %%
df_tips[df_tips["total_bill"].between(10, 20, inclusive = "neither")] # total_bill degeri 10 ile 20 arasinda olan satirlari dondurur (10 ve 20 dahil degil)
# inclusive parametresi ile sinir degerlerinin dahil edilip edilmeyecegi belirlenebilir, "both", "neither", "left", "right" degerleri alabilir
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 8         15.04  1.96    Male     No   Sun  Dinner     2              7.52
# 9         14.78  3.23    Male     No   Sun  Dinner     2              7.39
# 10        10.27  1.71    Male     No   Sun  Dinner     2              5.14
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2              7.76
# 235       10.07  1.25    Male     No   Sat  Dinner     2              5.04
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2              6.30
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# 0    Christy Cunningham  3560325168603410    Sun2959
# 1        Douglas Tucker  4478071379779230    Sun4608
# 8       Joseph Mcdonald  3522866365840377    Sun6820
# 9         Jerome Abbott  3532124519049786    Sun3775
# 10        William Riley      566287581219    Sun2546
# ..                  ...               ...        ...
# 234       Tracy Douglas  4097938155941930    Sat7220
# 235       Sean Gonzalez  3534021246117605    Sat4615
# 236       Matthew Myers  3543676378973965    Sat5032
# 242        Dennis Dixon     4375220550950      Sat17
# 243     Michelle Hardin  3511451626698139    Thur672
#
# [130 rows x 11 columns]

# %%
df_tips["total_bill"].nlargest(3) # total_bill sutunundaki en yuksek 3 DEGERI dondurur
# Out:
# 170    50.81
# 212    48.33
# 59     48.27
# Name: total_bill, dtype: float64

# %%
df_tips.nlargest(3, "total_bill") # total_bill sutunundaki en yuksek 3 SATIRI dondurur
# Out:
#      total_bill    tip   sex smoker  day    time  size  price_per_person  \
# 170       50.81  10.00  Male    Yes  Sat  Dinner     3             16.94
# 212       48.33   9.00  Male     No  Sat  Dinner     4             12.08
# 59        48.27   6.73  Male     No  Sat  Dinner     4             12.07
#
#           Payer Name         CC Number Payment ID
# 170    Gregory Clark  5473850968388236    Sat1954
# 212  Alex Williamson      676218815212    Sat4590
# 59       Brian Ortiz  6596453823950595    Sat8139

# %%
df_tips.sort_values(by = "total_bill", ascending = False).head(3) # ayni islem sort_values ile yapilabilir
# Out:
#      total_bill    tip   sex smoker  day    time  size  price_per_person  \
# 170       50.81  10.00  Male    Yes  Sat  Dinner     3             16.94
# 212       48.33   9.00  Male     No  Sat  Dinner     4             12.08
# 59        48.27   6.73  Male     No  Sat  Dinner     4             12.07
#
#           Payer Name         CC Number Payment ID
# 170    Gregory Clark  5473850968388236    Sat1954
# 212  Alex Williamson      676218815212    Sat4590
# 59       Brian Ortiz  6596453823950595    Sat8139

# %%
df_tips.nsmallest(3, "total_bill") # total_bill sutunundaki en kucuk 3 SATIRI dondurur
# Out:
#      total_bill  tip     sex smoker  day    time  size  price_per_person  \
# 67         3.07  1.0  Female    Yes  Sat  Dinner     1              3.07
# 92         5.75  1.0  Female    Yes  Fri  Dinner     2              2.88
# 111        7.25  1.0  Female     No  Sat  Dinner     1              7.25
#
#         Payer Name         CC Number Payment ID
# 67   Tiffany Brock  4359488526995267    Sat3455
# 92    Leah Ramirez  3508911676966392    Fri3780
# 111    Terri Jones  3559221007826887    Sat4801

# %%
df_tips["total_bill"].nsmallest(3) # total_bill sutunundaki en kucuk 3 DEGERI dondurur
# Out:
# 67     3.07
# 92     5.75
# 111    7.25
# Name: total_bill, dtype: float64

# %%
df_tips.nsmallest(3, ["tip", "total_bill"]) # once tip sonra total_bill sutununa gore en kucuk 3 SATIRI dondurur
# Out:
#      total_bill  tip     sex smoker  day    time  size  price_per_person  \
# 67         3.07  1.0  Female    Yes  Sat  Dinner     1              3.07
# 92         5.75  1.0  Female    Yes  Fri  Dinner     2              2.88
# 111        7.25  1.0  Female     No  Sat  Dinner     1              7.25
#
#         Payer Name         CC Number Payment ID
# 67   Tiffany Brock  4359488526995267    Sat3455
# 92    Leah Ramirez  3508911676966392    Fri3780
# 111    Terri Jones  3559221007826887    Sat4801
